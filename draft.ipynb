# %%
import pandas as pd
import numpy as np
import re

pd.set_option('display.max_columns', None)  # me muestre todas las columnas
pd.set_option('display.max_colwidth', 100)  #me muestre más caracteres por columna.

import warnings
warnings.filterwarnings('ignore')

# %%
acto = pd.read_csv('data/actor.csv', encoding= "ISO-8859-1") 
cate = pd.read_csv('data/category.csv', encoding= "ISO-8859-1") 
film = pd.read_csv('data/film.csv', encoding= "ISO-8859-1") 
inve = pd.read_csv('data/inventory.csv', encoding= "ISO-8859-1") 
lang = pd.read_csv('data/language.csv', encoding= "ISO-8859-1") 
old = pd.read_csv('data/old_HDD.csv', encoding= "ISO-8859-1") 
rent = pd.read_csv('data/rental.csv', encoding= "ISO-8859-1")

# %%
print(dact.columns)
print(dcat.columns)
print(dfil.columns)
print(dinv.columns)
print(dlan.columns)
print(dold.columns)
print(dren.columns)
# Out:
# Index(['actor_id', 'first_name', 'last_name', 'last_update'], dtype='object')
# Index(['category_id', 'name', 'last_update'], dtype='object')
# Index(['film_id', 'title', 'description', 'release_year', 'language_id',
#        'original_language_id', 'rental_duration', 'rental_rate', 'length',
#        'replacement_cost', 'rating', 'special_features', 'last_update'],
#       dtype='object')
# Index(['inventory_id', 'film_id', 'store_id', 'last_update'], dtype='object')
# Index(['language_id', 'name', 'last_update'], dtype='object')
# Index(['first_name', 'last_name', 'title', 'release_year', 'category_id'], dtype='object')
# Index(['rental_id', 'rental_date', 'inventory_id', 'customer_id',
#        'return_date', 'staff_id', 'last_update'],
#       dtype='object')

# %%
dact = dact[['actor_id', 'first_name', 'last_name']]

# %%
dact.head(50)
# Out:
#     actor_id first_name     last_name
# 0          1   PENELOPE       GUINESS
# 1          2       NICK      WAHLBERG
# 2          3         ED         CHASE
# 3          4   JENNIFER         DAVIS
# 4          5     JOHNNY  LOLLOBRIGIDA
# 5          6      BETTE     NICHOLSON
# 6          7      GRACE        MOSTEL
# 7          8    MATTHEW     JOHANSSON
# 8          9        JOE         SWANK
# 9         10  CHRISTIAN         GABLE
# 10        11       ZERO          CAGE
# 11        12       KARL         BERRY
# 12        13        UMA          WOOD
# 13        14     VIVIEN        BERGEN
# 14        15       CUBA       OLIVIER
# 15        16       FRED       COSTNER
# 16        17      HELEN        VOIGHT
# 17        18        DAN          TORN
# 18        19        BOB       FAWCETT
# 19        20    LUCILLE         TRACY
# 20        21    KIRSTEN       PALTROW
# 21        22      ELVIS          MARX
# 22        23     SANDRA        KILMER
# 23        24    CAMERON        STREEP
# ...

# %%
dcat = dcat[['category_id', 'name']]

# %%
dcat
# Out:
#     category_id         name
# 0             1       Action
# 1             2    Animation
# 2             3     Children
# 3             4     Classics
# 4             5       Comedy
# 5             6  Documentary
# 6             7        Drama
# 7             8       Family
# 8             9      Foreign
# 9            10        Games
# 10           11       Horror
# 11           12        Music
# 12           13          New
# 13           14       Sci-Fi
# 14           15       Sports
# 15           16       Travel

# %%
lst_f = list(dfil.columns)

# %%
lst_f = lst_f[:-1]

# %%
lst_f
# Out:
# ['film_id',
#  'title',
#  'description',
#  'release_year',
#  'language_id',
#  'original_language_id',
#  'rental_duration',
#  'rental_rate',
#  'length',
#  'replacement_cost',
#  'rating',
#  'special_features']

# %%
dfil = dfil[lst_f]

# %%
dfil.rating.value_counts()
# Out:
# PG-13    223
# NC-17    210
# R        195
# PG       194
# G        178
# Name: rating, dtype: int64

# %%
dfil
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                                                                              description  \
# 0       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1    A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient C...
# 2       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# ...

# %%
dinv.store_id.value_counts()
# Out:
# 1    503
# 2    497
# Name: store_id, dtype: int64

# %%
dold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    1000 non-null   object
#  1   last_name     1000 non-null   object
#  2   title         1000 non-null   object
#  3   release_year  1000 non-null   int64
#  4   category_id   1000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB

# %%
dold[dold.last_name == 'DAVIS']
# Out:
#    first_name last_name                 title  release_year  category_id
# 66   JENNIFER     DAVIS  ANACONDA CONFESSIONS          2006            2
# 67   JENNIFER     DAVIS           ANGELS LIFE          2006           13
# 68   JENNIFER     DAVIS   BAREFOOT MANCHURIAN          2006            1
# 69   JENNIFER     DAVIS          BED HIGHBALL          2006            6
# 70   JENNIFER     DAVIS          BLADE POLISH          2006            7
# 71   JENNIFER     DAVIS     BOONDOCK BALLROOM          2006           16
# 72   JENNIFER     DAVIS      GHOSTBUSTERS ELF          2006            2
# 73   JENNIFER     DAVIS          GREEDY ROOTS          2006            7
# 74   JENNIFER     DAVIS        HANOVER GALAXY          2006           12
# 75   JENNIFER     DAVIS      INSTINCT AIRPORT          2006           15
# 76   JENNIFER     DAVIS         JUMANJI BLADE          2006           13
# 77   JENNIFER     DAVIS        NATIONAL STORY          2006            6
# ...

# %%
dact
# Out:
#      actor_id first_name     last_name
# 0           1   PENELOPE       GUINESS
# 1           2       NICK      WAHLBERG
# 2           3         ED         CHASE
# 3           4   JENNIFER         DAVIS
# 4           5     JOHNNY  LOLLOBRIGIDA
# ..        ...        ...           ...
# 195       196       BELA        WALKEN
# 196       197      REESE          WEST
# 197       198       MARY        KEITEL
# 198       199      JULIA       FAWCETT
# 199       200      THORA        TEMPLE
#
# [200 rows x 3 columns]

# %%
dact[dact.last_name == 'DAVIS']
# Out:
#      actor_id first_name last_name
# 3           4   JENNIFER     DAVIS
# 100       101      SUSAN     DAVIS
# 109       110      SUSAN     DAVIS

# %%
(dact['first_name'] + dact['last_name']).value_counts().head(60)
# Out:
# SUSANDAVIS           2
# EWANGOODING          1
# DARYLCRAWFORD        1
# GRETAKEITEL          1
# JANEJACKMAN          1
# ADAMHOPPER           1
# RICHARDPENN          1
# GENEHOPKINS          1
# RITAREYNOLDS         1
# EDMANSFIELD          1
# MORGANWILLIAMS       1
# LUCILLEDEE           1
# WHOOPIHURT           1
# GEOFFREYHESTON       1
# CATEHARRIS           1
# JADARYDER            1
# RIVERDEAN            1
# ANGELAWITHERSPOON    1
# KIMALLEN             1
# ALBERTJOHANSSON      1
# FAYWINSLET           1
# EMILYDEE             1
# RUSSELLTEMPLE        1
# JAYNENOLTE           1
# CATEMCQUEEN          1
# PENELOPEGUINESS      1
# FRANCESTOMEI         1
# ALBERTNOLTE          1
# MATTHEWLEIGH         1
# PENELOPECRONYN       1
# SIDNEYCROWE          1
# GROUCHODUNST         1
# GINADEGENERES        1
# WARRENNOLTE          1
# SYLVESTERDERN        1
# CAMERONZELLWEGER     1
# RUSSELLBACALL        1
# MORGANHOPKINS        1
# MORGANMCDORMAND      1
# HARRISONBALE         1
# ...

# %%
dold
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
dfil.head(25)
# Out:
#     film_id                 title  \
# 0         1      ACADEMY DINOSAUR
# 1         2        ACE GOLDFINGER
# 2         3      ADAPTATION HOLES
# 3         4      AFFAIR PREJUDICE
# 4         5           AFRICAN EGG
# 5         6          AGENT TRUMAN
# 6         7       AIRPLANE SIERRA
# 7         8       AIRPORT POLLOCK
# 8         9         ALABAMA DEVIL
# 9        10      ALADDIN CALENDAR
# 10       11       ALAMO VIDEOTAPE
# 11       12        ALASKA PHANTOM
# 12       13           ALI FOREVER
# 13       14        ALICE FANTASIA
# 14       15          ALIEN CENTER
# 15       16       ALLEY EVOLUTION
# 16       17            ALONE TRIP
# 17       18         ALTER VICTORY
# 18       19          AMADEUS HOLY
# 19       20   AMELIE HELLFIGHTERS
# 20       21       AMERICAN CIRCUS
# 21       22     AMISTAD MIDSUMMER
# 22       23  ANACONDA CONFESSIONS
# 23       24      ANALYZE HOOSIERS
# 24       25           ANGELS LIFE
#
# ...

# %%
dinv
# Out:
#      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]

# %%
dren
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
dfil.iloc[:223]
# Out:
#      film_id                   title  \
# 0          1        ACADEMY DINOSAUR
# 1          2          ACE GOLDFINGER
# 2          3        ADAPTATION HOLES
# 3          4        AFFAIR PREJUDICE
# 4          5             AFRICAN EGG
# ..       ...                     ...
# 218      219            DEEP CRUSADE
# 219      220          DEER VIRGINIAN
# 220      221  DELIVERANCE MULHOLLAND
# 221      222         DESERT POSEIDON
# 222      223            DESIRE ALIEN
#
#                                                                                              description  \
# 0       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1    A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient C...
# 2       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# ...

# %%
len(dold['title'].unique())       # PELIS ÚNICAS EN OLD HDD
# Out:
# 614

# %%
len((dold['first_name'] + dold['last_name']).unique())    #ACTORES ÚNICOS EN OLD HDD
# Out:
# 39

# %%
dold
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
dren
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
dold
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
dinv
# Out:
#      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]

# %%
dold['title'].unique()      # PELIS ÚNICAS EN OLD HDD len = 614
# Out:
# array(['ACADEMY DINOSAUR', 'ANACONDA CONFESSIONS', 'ANGELS LIFE',
#        'BULWORTH COMMANDMENTS', 'CHEAPER CLYDE', 'COLOR PHILADELPHIA',
#        'ELEPHANT TROJAN', 'GLEAMING JAWBREAKER', 'HUMAN GRAFFITI',
#        'KING EVOLUTION', 'LADY STAGE', 'LANGUAGE COWBOY',
#        'MULHOLLAND BEAST', 'OKLAHOMA JUMANJI', 'RULES HUMAN',
#        'SPLASH GUMP', 'VERTIGO NORTHWEST', 'WESTWARD SEABISCUIT',
#        'WIZARD COLDBLOODED', 'ADAPTATION HOLES', 'APACHE DIVINE',
#        'BABY HALL', 'BULL SHAWSHANK', 'CHAINSAW UPTOWN',
#        'CHISUM BEHAVIOR', 'DESTINY SATURDAY', 'DRACULA CRYSTAL',
#        'FIGHT JAWBREAKER', 'FLASH WARS', 'GILBERT PELICAN',
#        'GOODFELLAS SALUTE', 'HAPPINESS UNITED', 'INDIAN LOVE',
#        'JEKYLL FROGMEN', 'JERSEY SASSY', 'LIAISONS SWEET', 'LUCKY FLYING',
#        'MAGUIRE APACHE', 'MALLRATS UNITED', 'MASK PEACH', 'ROOF CHAMPION',
#        'RUSHMORE MERMAID', 'SMILE EARRING', 'WARDROBE PHANTOM',
# ...

# %%
(dold['first_name'] + dold['last_name']).unique()    #ACTORES ÚNICOS EN OLD HDD len = 39
# Out:
# array(['PENELOPEGUINESS', 'NICKWAHLBERG', 'EDCHASE', 'JENNIFERDAVIS',
#        'JOHNNYLOLLOBRIGIDA', 'BETTENICHOLSON', 'GRACEMOSTEL',
#        'MATTHEWJOHANSSON', 'JOESWANK', 'CHRISTIANGABLE', 'ZEROCAGE',
#        'KARLBERRY', 'UMAWOOD', 'VIVIENBERGEN', 'CUBAOLIVIER',
#        'FREDCOSTNER', 'HELENVOIGHT', 'DANTORN', 'BOBFAWCETT',
#        'LUCILLETRACY', 'KIRSTENPALTROW', 'ELVISMARX', 'SANDRAKILMER',
#        'CAMERONSTREEP', 'KEVINBLOOM', 'RIPCRAWFORD', 'JULIAMCQUEEN',
#        'WOODYHOFFMAN', 'ALECWAYNE', 'SANDRAPECK', 'SISSYSOBIESKI',
#        'TIMHACKMAN', 'MILLAPECK', 'AUDREYOLIVIER', 'JUDYDEAN',
#        'BURTDUKAKIS', 'VALBOLGER', 'TOMMCKELLEN', 'GOLDIEBRODY'],
#       dtype=object)

# %%
uniq_tit_old = list(dold['title'].unique())

# %%
dfil
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                                                                              description  \
# 0       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1    A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient C...
# 2       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# ...

# %%
(dold['title'] == dfil['title']).value_counts()
# Out:
# False    997
# True       3
# Name: title, dtype: int64

# %%
# Supongamos que dold y dfilm son tus dataframes

# Obtén los valores únicos en la columna "title" de ambas tablas
dold_titles = dold['title'].unique()
dfil_titles = dfil['title'].unique()

# Crea una nueva columna "match" en dfilm que indica si el valor en "title" está en dold
dfil['match'] = dfil['title'].isin(dold_titles)

# Filtra dfilm para obtener solo las filas en las que match es True
result = dfil[dfil['match'] == True]

# Muestra los valores únicos en "title" que están presentes en ambas tablas
len(result['title'].unique())
# Out:
# 614

# %%
dfil['match']
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998    False
# 999    False
# Name: match, Length: 1000, dtype: bool

# %%
dold
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
dinv
# Out:
#      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]

# %%
dold
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
dfil
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                                                                              description  \
# 0       A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies
# 1    A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient C...
# 2       A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory
# 3           A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank
# ...

# %%
dren.customer_id.max()
# Out:
# 597

# %%
dinv.iloc[145]
# Out:
# inventory_id                    146
# film_id                          31
# store_id                          1
# last_update     2006-02-15 05:09:17
# Name: 145, dtype: object

# %%
dfil.iloc[31]
# Out:
# film_id                                                                                                                32
# title                                                                                                APOCALYPSE FLAMINGOS
# description             A Astounding Story of a Dog And a Squirrel who must Defeat a Woman in An Abandoned Amusement Park
# release_year                                                                                                         2006
# language_id                                                                                                             1
# original_language_id                                                                                                  NaN
# rental_duration                                                                                                         6
# rental_rate                                                                                                          4.99
# ...

# %%
dinv
# Out:
#      inventory_id  film_id  store_id          last_update
# 0               1        1         1  2006-02-15 05:09:17
# 1               2        1         1  2006-02-15 05:09:17
# 2               3        1         1  2006-02-15 05:09:17
# 3               4        1         1  2006-02-15 05:09:17
# 4               5        1         2  2006-02-15 05:09:17
# ..            ...      ...       ...                  ...
# 995           996      222         2  2006-02-15 05:09:17
# 996           997      222         2  2006-02-15 05:09:17
# 997           998      222         2  2006-02-15 05:09:17
# 998           999      223         2  2006-02-15 05:09:17
# 999          1000      223         2  2006-02-15 05:09:17
#
# [1000 rows x 4 columns]

# %%
dren.inventory_id.max()
# Out:
# 4581

# %%
dren.tail(60)
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 940        942  2005-05-30 15:05:47          4279          473
# 941        943  2005-05-30 15:20:19          3737           57
# 942        944  2005-05-30 15:26:24           151          131
# 943        945  2005-05-30 15:33:17          1441          357
# 944        946  2005-05-30 15:35:08          1264          486
# 945        947  2005-05-30 15:36:57          4478           62
# 946        948  2005-05-30 15:44:27           585          245
# 947        949  2005-05-30 15:50:39          2202          368
# 948        950  2005-05-30 16:06:08           491           83
# 949        951  2005-05-30 16:10:35          1395           59
# 950        952  2005-05-30 16:28:07          4389          311
# 951        953  2005-05-30 16:34:02          2194          210
# 952        954  2005-05-30 16:57:29          1231          297
# 953        955  2005-05-30 16:59:03          4140          301
# ...

# %%
dinv.head(20)
# Out:
#     inventory_id  film_id  store_id          last_update
# 0              1        1         1  2006-02-15 05:09:17
# 1              2        1         1  2006-02-15 05:09:17
# 2              3        1         1  2006-02-15 05:09:17
# 3              4        1         1  2006-02-15 05:09:17
# 4              5        1         2  2006-02-15 05:09:17
# 5              6        1         2  2006-02-15 05:09:17
# 6              7        1         2  2006-02-15 05:09:17
# 7              8        1         2  2006-02-15 05:09:17
# 8              9        2         2  2006-02-15 05:09:17
# 9             10        2         2  2006-02-15 05:09:17
# 10            11        2         2  2006-02-15 05:09:17
# 11            12        3         2  2006-02-15 05:09:17
# 12            13        3         2  2006-02-15 05:09:17
# 13            14        3         2  2006-02-15 05:09:17
# 14            15        3         2  2006-02-15 05:09:17
# ...

# %%
dfil.head(60)
# Out:
#     film_id                        title  \
# 0         1             ACADEMY DINOSAUR
# 1         2               ACE GOLDFINGER
# 2         3             ADAPTATION HOLES
# 3         4             AFFAIR PREJUDICE
# 4         5                  AFRICAN EGG
# 5         6                 AGENT TRUMAN
# 6         7              AIRPLANE SIERRA
# 7         8              AIRPORT POLLOCK
# 8         9                ALABAMA DEVIL
# 9        10             ALADDIN CALENDAR
# 10       11              ALAMO VIDEOTAPE
# 11       12               ALASKA PHANTOM
# 12       13                  ALI FOREVER
# 13       14               ALICE FANTASIA
# 14       15                 ALIEN CENTER
# 15       16              ALLEY EVOLUTION
# 16       17                   ALONE TRIP
# 17       18                ALTER VICTORY
# 18       19                 AMADEUS HOLY
# 19       20          AMELIE HELLFIGHTERS
# 20       21              AMERICAN CIRCUS
# 21       22            AMISTAD MIDSUMMER
# ...

# %%
dinv.head(60)
# Out:
#     inventory_id  film_id  store_id          last_update
# 0              1        1         1  2006-02-15 05:09:17
# 1              2        1         1  2006-02-15 05:09:17
# 2              3        1         1  2006-02-15 05:09:17
# 3              4        1         1  2006-02-15 05:09:17
# 4              5        1         2  2006-02-15 05:09:17
# 5              6        1         2  2006-02-15 05:09:17
# 6              7        1         2  2006-02-15 05:09:17
# 7              8        1         2  2006-02-15 05:09:17
# 8              9        2         2  2006-02-15 05:09:17
# 9             10        2         2  2006-02-15 05:09:17
# 10            11        2         2  2006-02-15 05:09:17
# 11            12        3         2  2006-02-15 05:09:17
# 12            13        3         2  2006-02-15 05:09:17
# 13            14        3         2  2006-02-15 05:09:17
# 14            15        3         2  2006-02-15 05:09:17
# ...

# %%
dren['return_date'] = pd.to_datetime(dren['return_date'])
dren['rental_date'] = pd.to_datetime(dren['rental_date'])

# %%
dren['days'] = dren['return_date'] - dren['rental_date']

# %%
dren.days = dren.days.astype(str)

# %%
dren.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   int64
#  1   rental_date   1000 non-null   datetime64[ns]
#  2   inventory_id  1000 non-null   int64
#  3   customer_id   1000 non-null   int64
#  4   return_date   1000 non-null   datetime64[ns]
#  5   staff_id      1000 non-null   int64
#  6   last_update   1000 non-null   object
#  7   days          1000 non-null   object
# dtypes: datetime64[ns](2), int64(4), object(2)
# memory usage: 62.6+ KB

# %%
dren['days'] = dren['days'].apply(lambda x: x[0])

# %%
dren['film_id'] = dfil['film_id']
# Out:
#      rental_id         rental_date  inventory_id  customer_id  \
# 0            1 2005-05-24 22:53:30           367          130
# 1            2 2005-05-24 22:54:33          1525          459
# 2            3 2005-05-24 23:03:39          1711          408
# 3            4 2005-05-24 23:04:41          2452          333
# 4            5 2005-05-24 23:05:21          2079          222
# ..         ...                 ...           ...          ...
# 995        997 2005-05-31 00:08:25          4243          216
# 996        998 2005-05-31 00:16:57          3395          389
# 997        999 2005-05-31 00:25:10          4433          413
# 998       1000 2005-05-31 00:25:56          1774          332
# 999       1001 2005-05-31 00:46:31          1498           64
#
#             return_date  staff_id          last_update days
# 0   2005-05-26 22:04:30         1  2006-02-15 21:30:53    1
# 1   2005-05-28 19:40:33         1  2006-02-15 21:30:53    3
# ...

# %%
dinv = pd.concat([dinv, pd.get_dummies(dinv['store_id'], prefix='Store')], axis=1)

# %%
dinv
# Out:
#      inventory_id  film_id  store_id          last_update  Store_1  Store_2
# 0               1        1         1  2006-02-15 05:09:17        1        0
# 1               2        1         1  2006-02-15 05:09:17        1        0
# 2               3        1         1  2006-02-15 05:09:17        1        0
# 3               4        1         1  2006-02-15 05:09:17        1        0
# 4               5        1         2  2006-02-15 05:09:17        0        1
# ..            ...      ...       ...                  ...      ...      ...
# 995           996      222         2  2006-02-15 05:09:17        0        1
# 996           997      222         2  2006-02-15 05:09:17        0        1
# 997           998      222         2  2006-02-15 05:09:17        0        1
# 998           999      223         2  2006-02-15 05:09:17        0        1
# 999          1000      223         2  2006-02-15 05:09:17        0        1
#
# [1000 rows x 6 columns]
